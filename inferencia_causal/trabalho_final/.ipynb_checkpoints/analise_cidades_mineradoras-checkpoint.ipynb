# %% [markdown]
# *Notebook com o trabalho final da disciplina de Métodos em Inferência Causal do Master em Jornalismo de Dados, Automação e Data Storytelling do Insper, ministrada por Lucas M. Novaes.*
#
# **Grupo**: *Bianca Muniz, Jamile Santana, Jéssica Avelar e Thiago Araújo*
#
# Para a análise, selecionamos cidades de Minas Gerais que possuem barragem de rejeito e têm forte influência da mineração: Barão de Cocais, Brumadinho, Catas Altas, Itabira, Nova Lima, Mariana, Ouro Preto, São Gonçalo do Rio Abaixo.

# %% [markdown]
# ## **Algumas perguntas**

# %% [markdown]
# ### Doações:
# 1. Quem recebeu mais doações;
# 2. Qual a média das doações
# 2. Ranking de doações para cada candidato;   **Não sei como fazer**
# 3. Quem doou mais;
# 4. Tem empresa/pessoa que doou para mais de um candidato
# 5. Total recebido por partido.
#
# ### Despesas:
# 1. Quem gastou mais?
# 2. Qual a média dos gastos?
# 3. Ranking de despesas por candidato.
# 4. Quais fornecedores ganharam mais dinheiro?
# 5. Os candidatos gastaram com os mesmos fornecedores?
# 6. Total gasto por categoria de despesas.
# 7. Média de gastos dos partidos por candidato
# 8. O candidato com mais gastos venceu? Teve poucos/muitos votos?
#
# ### Para além das bases:
# 1. Tem candidatos envolvidos em esquemas?
# 2. Quais candidatos caçados?
# 3. Quais empresas que financiam esses candidatos?
# 4. Olhar processo de cassação, sócios das empresas envolvidas no processo
# 5. O que muda com a doação de pessoa física/pessoa jurídica

# %% [markdown]
# ## **Preparando as bases**

# %%
import pandas as pd
import csv

# %%
desp16 = pd.read_csv("despesas_candidatos_2016_MG.txt", sep=";", encoding="latin_1", error_bad_lines=False)
rec16 = pd.read_csv("receitas_candidatos_2016_MG.txt", sep=";", encoding="latin_1", error_bad_lines=False)
# Out:
# C:\Users\bianc\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (16) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
rec16["Valor receita"] = rec16["Valor receita"].apply(lambda x: str(x).replace(",", "."))
desp16["Valor despesa"] = desp16["Valor despesa"].apply(lambda x: str(x).replace(",", "."))

# %%
desp16 = desp16.drop(["Cód. Eleição", "Data e hora", "CNPJ Prestador Conta", "UF", "Sigla da UE",
                   "Nome da UE", "CPF do vice/suplente", "Tipo de documento", "Número do documento",
                   "Cod setor econômico do fornecedor"],
                  axis = 1)
desp16
# Out:
#                    Desc. Eleição  Sequencial Candidato Sigla  Partido  \
# 0       Eleições Municipais 2016          130000085573            PMN
# 1       Eleições Municipais 2016          130000085573            PMN
# 2       Eleições Municipais 2016          130000085573            PMN
# 3       Eleições Municipais 2016          130000085573            PMN
# 4       Eleições Municipais 2016          130000085649            PTB
# ...                          ...                   ...            ...
# 885540  Eleições Municipais 2016          130000007191            DEM
# 885541  Eleições Municipais 2016          130000036454            PSC
# 885542  Eleições Municipais 2016          130000012571             PP
# 885543  Eleições Municipais 2016          130000012571             PP
# 885544  Eleições Municipais 2016          130000042869           PMDB
#
#         Número candidato     Cargo                  Nome candidato  \
# 0                  33555  Vereador          NELI PEREIRA DE AQUINO
# 1                  33555  Vereador          NELI PEREIRA DE AQUINO
# 2                  33555  Vereador          NELI PEREIRA DE AQUINO
# 3                  33555  Vereador          NELI PEREIRA DE AQUINO
# 4                     14  Prefeito     WANDERSON OLIVEIRA TEIXEIRA
# ...                  ...       ...                             ...
# 885540             25999  Vereador      WALTENCIR BALBINO DE SOUZA
# 885541             20123  Vereador  LAURINDA DA LUZ FERREIRA ROCHA
# 885542             11123  Vereador                 NILSON FERREIRA
# 885543             11123  Vereador                 NILSON FERREIRA
# 885544                15  Prefeito            RONALDO PEREIRA DIAS
#
#         CPF do candidato CPF/CNPJ do fornecedor  \
# 0             3553151650         19738635000119
# 1             3553151650         19738635000119
# 2             3553151650         19738635000119
# 3             3553151650         19738635000119
# 4             7612886600         19738635000119
# ...                  ...                    ...
# 885540       96471204604            10406134626
# 885541         551048603              551048603
# 885542       37118161691         25499387000101
# 885543       37118161691         25499387000101
# 885544       10043467865            54984467649
#
#                                      Nome do fornecedor  \
# 0               POLIMARKET COMUNICACAO VISUAL LTDA - ME
# 1               POLIMARKET COMUNICACAO VISUAL LTDA - ME
# 2               POLIMARKET COMUNICACAO VISUAL LTDA - ME
# 3               POLIMARKET COMUNICACAO VISUAL LTDA - ME
# 4               POLIMARKET COMUNICACAO VISUAL LTDA - ME
# ...                                                 ...
# 885540                          CASSIO GONCALVES MACIEL
# 885541                   LAURINDA DA LUZ FERREIRA ROCHA
# 885542  ELEICAO 2016 CLECIO GONCALVES DA SILVA PREFEITO
# 885543  ELEICAO 2016 CLECIO GONCALVES DA SILVA PREFEITO
# 885544                   ROSELI APARECIDA PERLOTTI DIAS
#
#                    Nome do fornecedor (Receita Federal)  \
# 0               POLIMARKET COMUNICACAO VISUAL LTDA - ME
# 1               POLIMARKET COMUNICACAO VISUAL LTDA - ME
# 2               POLIMARKET COMUNICACAO VISUAL LTDA - ME
# 3               POLIMARKET COMUNICACAO VISUAL LTDA - ME
# 4               POLIMARKET COMUNICACAO VISUAL LTDA - ME
# ...                                                 ...
# 885540                          CASSIO GONCALVES MACIEL
# 885541                   LAURINDA DA LUZ FERREIRA ROCHA
# 885542  ELEICAO 2016 CLECIO GONCALVES DA SILVA PREFEITO
# 885543  ELEICAO 2016 CLECIO GONCALVES DA SILVA PREFEITO
# 885544                   ROSELI APARECIDA PERLOTTI DIAS
#
#                             Setor econômico do fornecedor     Data da despesa  \
# 0       Serviços combinados de escritório e apoio admi...  01/09/201600:00:00
# 1       Serviços combinados de escritório e apoio admi...  01/09/201600:00:00
# 2       Serviços combinados de escritório e apoio admi...  01/09/201600:00:00
# 3       Serviços combinados de escritório e apoio admi...  01/09/201600:00:00
# 4       Serviços combinados de escritório e apoio admi...  31/08/201600:00:00
# ...                                                   ...                 ...
# 885540                                              #NULO  30/08/201600:00:00
# 885541                                              #NULO  31/08/201600:00:00
# 885542               Atividades de organizações políticas  03/09/201600:00:00
# 885543               Atividades de organizações políticas  10/09/201600:00:00
# 885544                                              #NULO  21/09/201600:00:00
#
#        Valor despesa                                       Tipo despesa  \
# 0               1890                Publicidade por materiais impressos
# 1                900                Publicidade por materiais impressos
# 2                980                Publicidade por materiais impressos
# 3               1400                Publicidade por materiais impressos
# 4               2400                           Publicidade por adesivos
# ...              ...                                                ...
# 885540           500  Baixa de Estimaveis - Serviços prestados por t...
# 885541       2298.24  Baixa de Estimaveis - Cessão ou locação de veí...
# 885542            25  Baixa de Estimaveis - Publicidade por materiai...
# 885543           145  Baixa de Estimaveis - Publicidade por materiai...
# 885544          1200  Baixa de Estimaveis - Cessão ou locação de veí...
#
#                                      Descriçao da despesa
# 0       SANTINHOS AP 75GR -10X7CM - 4X1COR (COLABORADO...
# 1                           CARTAZ AP75GR 21X30CM 4X0 COR
# 2                        CARTÃO DE VISITA 9X5CM - 4X4 COR
# 3       SANTINHOS AP 75GR - 10X7 CM - 4X1 COR (COLABOR...
# 4                        ADESIVOS PARACHOQUE 30X8CM VINIL
# ...                                                   ...
# 885540             PRESTAÇÃO DE SERVIÇOS DE CONTABILIDADE
# 885541  CESSÃO AUTOMOVEL· GM/MERIVA·2003/2003·PLCA HAA...
# 885542  320.000 SANTINHOS SENDO 10.000 SANTINHOS PARA ...
# 885543  SANTINHOS CASADOS 10X7 CM 4X1 COR PARA O CANDI...
# 885544  CESSAO DE USO DE UM CAMINHAO PLACA HHF-1100· R...
#
# [885545 rows x 15 columns]

# %%
# Selecionando as variáveis de interesse:
rec16 = rec16.drop(["Cód. Eleição", "Data e hora", "CNPJ Prestador Conta", "UF", "Sigla da UE",
                            "Nome da UE", "CPF do vice/suplente", "Numero Recibo Eleitoral", "Numero do documento",
                            "Sigla UE doador", "Número partido doador", "Número candidato doador",
                            "Cod setor econômico do doador", "Setor econômico do doador originário",
                            "Tipo doador originário"],
                           axis = 1)
rec16
# Out:
#                    Desc. Eleição  Sequencial Candidato Sigla  Partido  \
# 0       Eleições Municipais 2016          130000064799             PP
# 1       Eleições Municipais 2016          130000020645            PMB
# 2       Eleições Municipais 2016          130000020645            PMB
# 3       Eleições Municipais 2016          130000025654             PV
# 4       Eleições Municipais 2016          130000025654             PV
# ...                          ...                   ...            ...
# 471032  Eleições Municipais 2016          130000054040           PSDC
# 471033  Eleições Municipais 2016          130000054040           PSDC
# 471034  Eleições Municipais 2016          130000054040           PSDC
# 471035  Eleições Municipais 2016          130000054040           PSDC
# 471036  Eleições Municipais 2016          130000054040           PSDC
#
#         Numero candidato     Cargo                    Nome candidato  \
# 0                  11200  Vereador               MARIA CATARINA NETO
# 1                  35135  Vereador            KAMILA RODRIGUES NERES
# 2                  35135  Vereador            KAMILA RODRIGUES NERES
# 3                  43555  Vereador              JACI RICARDO VIRIATO
# 4                  43555  Vereador              JACI RICARDO VIRIATO
# ...                  ...       ...                               ...
# 471032             27000  Vereador  MARCOS DONALD GONÇALVES VILLEGAS
# 471033             27000  Vereador  MARCOS DONALD GONÇALVES VILLEGAS
# 471034             27000  Vereador  MARCOS DONALD GONÇALVES VILLEGAS
# 471035             27000  Vereador  MARCOS DONALD GONÇALVES VILLEGAS
# 471036             27000  Vereador  MARCOS DONALD GONÇALVES VILLEGAS
#
#         CPF do candidato CPF/CNPJ do doador  \
# 0            10185086608     25860182000100
# 1             4932867131        05247472616
# 2             4932867131        47044411649
# 3            75509717653     25586558000121
# 4            75509717653     25586558000121
# ...                  ...                ...
# 471032       11459283821     25887168000191
# 471033       11459283821     25887168000191
# 471034       11459283821        11459283821
# 471035       11459283821        11459283821
# 471036       11459283821        11459283821
#
#                                         Nome do doador  \
# 0                             ALIRIO TIBURCIO DA SILVA
# 1                                      RODRIGO SBRUZZI
# 2                        MANOEL DELCI BATISTA DA SILVA
# 3          ELEIÇÕES 2016 LUIZ CARLOS DA SILVA PREFEITO
# 4          ELEIÇÕES 2016 LUIZ CARLOS DA SILVA PREFEITO
# ...                                                ...
# 471032  ELEIÇÃO 2016 JOSÉ DE FREITAS CORDEIRO PREFEITO
# 471033  ELEIÇÃO 2016 JOSÉ DE FREITAS CORDEIRO PREFEITO
# 471034                MARCOS DONALD GONÇALVES VILLEGAS
# 471035                MARCOS DONALD GONÇALVES VILLEGAS
# 471036                MARCOS DONALD GONÇALVES VILLEGAS
#
#                       Nome do doador (Receita Federal)  \
# 0       ELEICAO 2016 ALIRIO TIBURCIO DA SILVA PREFEITO
# 1                                      RODRIGO SBRUZZI
# 2                        MANOEL DELCI BATISTA DA SILVA
# 3           ELEICAO 2016 LUIZ CARLOS DA SILVA PREFEITO
# 4           ELEICAO 2016 LUIZ CARLOS DA SILVA PREFEITO
# ...                                                ...
# 471032  ELEICAO 2016 JOSE DE FREITAS CORDEIRO PREFEITO
# 471033  ELEICAO 2016 JOSE DE FREITAS CORDEIRO PREFEITO
# 471034                MARCOS DONALD GONCALVES VILLEGAS
# 471035                MARCOS DONALD GONCALVES VILLEGAS
# 471036                MARCOS DONALD GONCALVES VILLEGAS
#
#                    Setor econômico do doador     Data da receita  \
# 0       Atividades de organizações políticas  28/09/201600:00:00
# 1                                      #NULO  25/09/201600:00:00
# 2                                      #NULO  25/09/201600:00:00
# 3       Atividades de organizações políticas  16/09/201600:00:00
# 4       Atividades de organizações políticas  22/08/201600:00:00
# ...                                      ...                 ...
# 471032  Atividades de organizações políticas  28/09/201600:00:00
# 471033  Atividades de organizações políticas  06/09/201600:00:00
# 471034                                 #NULO  10/09/201600:00:00
# 471035                                 #NULO  10/09/201600:00:00
# 471036                                 #NULO  13/09/201600:00:00
#
#        Valor receita                   Tipo receita     Fonte recurso  \
# 0                160  Recursos de outros candidatos  Fundo Partidario
# 1                100    Recursos de pessoas físicas   Outros Recursos
# 2                100    Recursos de pessoas físicas   Outros Recursos
# 3                120  Recursos de outros candidatos   Outros Recursos
# 4              27.78  Recursos de outros candidatos   Outros Recursos
# ...              ...                            ...               ...
# 471032            35  Recursos de outros candidatos   Outros Recursos
# 471033            74  Recursos de outros candidatos   Outros Recursos
# 471034           1.7              Recursos próprios   Outros Recursos
# 471035          22.7              Recursos próprios   Outros Recursos
# 471036           500              Recursos próprios   Outros Recursos
#
#             Especie recurso  \
# 0                  Estimado
# 1                  Estimado
# 2                  Estimado
# 3                  Estimado
# 4                  Estimado
# ...                     ...
# 471032             Estimado
# 471033             Estimado
# 471034  Depósito em espécie
# 471035  Depósito em espécie
# 471036           Em espécie
#
#                                      Descricao da receita  \
# 0                                               SANTINHOS
# 1       PRESTAÇÃO DE SERVIÇOS DE CONTABILISTA NA CAMPA...
# 2       PRESTAÇÃO DE SERVIÇOS DE ADVOGADO NA CAMPANHA ...
# 3          ASSESSORIA JURIDICA FRENTE A JUSTIÇA ELEITORAL
# 4                                         2.000 SANTINHOS
# ...                                                   ...
# 471032                 CARTÃO/COLINHA 5X9 CM COM PREFEITO
# 471033      SANTÃO 10X14 CM - 4X4 - PREFEITO COM VEREADOR
# 471034                                              #NULO
# 471035                                              #NULO
# 471036                                              #NULO
#
#        CPF/CNPJ do doador originário Nome do doador originário  \
# 0                              #NULO                     #NULO
# 1                              #NULO                     #NULO
# 2                              #NULO                     #NULO
# 3                        14476487653      LUIZ CARLOS DA SILVA
# 4                              #NULO                     #NULO
# ...                              ...                       ...
# 471032                   24518611691  JOSÉ DE FREITAS CORDEIRO
# 471033                   24518611691  JOSÉ DE FREITAS CORDEIRO
# 471034                         #NULO                     #NULO
# 471035                         #NULO                     #NULO
# 471036                         #NULO                     #NULO
#
#        Nome do doador originário (Receita Federal)
# 0                                            #NULO
# 1                                            #NULO
# 2                                            #NULO
# 3                             LUIZ CARLOS DA SILVA
# 4                                            #NULO
# ...                                            ...
# 471032                    JOSE DE FREITAS CORDEIRO
# 471033                    JOSE DE FREITAS CORDEIRO
# 471034                                       #NULO
# 471035                                       #NULO
# 471036                                       #NULO
#
# [471037 rows x 20 columns]

# %%
# Selecionando os municípios de nosso interesse
## Barão de Cocais
barao_despesas2016 = desp16.loc[desp16["Sigla da UE"] == 41076]
barao_receitas2016 = rec16.loc[rec16["Sigla da UE"] == 41076]

## Brumadinho
brumadinho_despesas2016 = desp16.loc[desp16["Sigla da UE"] == 41793]
brumadinho_receitas2016 = rec16.loc[rec16["Sigla da UE"] == 41793]

## Catas Altas
catas_despesas2016 = desp16.loc[desp16["Sigla da UE"] == 41840]
catas_receitas2016 = rec16.loc[rec16["Sigla da UE"] == 41840]

## Itabira
itabira_despesas2016 = desp16.loc[desp16["Sigla da UE"] == 46337]
itabira_receitas2016 = rec16.loc[rec16["Sigla da UE"] == 46337]

## Nova Lima
lima_despesas2016 = desp16.loc[desp16["Sigla da UE"] == 48950]
lima_receitas2016 = rec16.loc[rec16["Sigla da UE"] == 48950]

## Mariana
mariana_despesas2016 = desp16.loc[desp16["Sigla da UE"] == 47996]
mariana_receitas2016 = rec16.loc[rec16["Sigla da UE"] == 47996]

## Ouro Preto
ouropreto_despesas2016 = desp16.loc[desp16["Sigla da UE"] == 49212]
ouropreto_receitas2016 = rec16.loc[rec16["Sigla da UE"] == 49212]

## São Gonçalo do Rio Abaixo
itabira_despesas2016 = desp16.loc[desp16["Sigla da UE"] == 52370]
itabira_receitas2016 = rec16.loc[rec16["Sigla da UE"] == 52370]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Sigla da UE'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-3d1bc3352a97> in <module>
#       1 # Selecionando os municípios de nosso interesse
#       2 ## Barão de Cocais
# ----> 3 barao_despesas2016 = desp16.loc[desp16["Sigla da UE"] == 41076]
#       4 barao_receitas2016 = rec16.loc[rec16["Sigla da UE"] == 41076]
#       5
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'Sigla da UE'

# %% [markdown]
# ## **Análise descritiva: Itabira**

# %% [markdown]
# ### Base doações

# %%
itabira_receitas2016_pref = itabira_receitas2016.loc[itabira_receitas2016["Cargo"] == "Prefeito"]
itabira_receitas2016_ver = itabira_receitas2016.loc[itabira_receitas2016["Cargo"] == "Vereador"]

# %%
# 1. Quem recebeu mais doações em Itabira - Prefeitos

itabira_receitas2016_pref["receita"] = itabira_receitas2016_pref.groupby(["Sigla  Partido", "CPF do candidato",
                                                    "Nome candidato"])["Valor receita"].transform("sum")
receitas_itabira_pref = (itabira_receitas2016_pref[["Sigla  Partido", "Nome candidato", "receita"]]).drop_duplicates().sort_values("receita",
                                                                                                                    ascending = False)
receitas_itabira_pref

# %%
# 1. Quem recebeu mais doações em Barão de Cocais - Vereadores

itabira_receitas2016_ver["receita"] = itabira_receitas2016_ver.groupby(["Sigla  Partido", "CPF do candidato",
                                                    "Nome candidato"])["Valor receita"].transform("sum")
receitas_itabira_ver = (itabira_receitas2016_ver[["Sigla  Partido", "Nome candidato", "receita"]]).drop_duplicates().sort_values("receita",
                                                                                                                    ascending = False)
receitas_itabira_ver.head(50)

# %%
# 2. Qual a média das doações - Prefeito

receitas_itabira_pref.describe()

# %%
# 2. Qual a média das doações - Vereadores

receitas_itabira_ver.describe()

# %%
# 4. Quem doou mais

itabira_receitas2016["receita"] = itabira_receitas2016.groupby(["CPF/CNPJ do doador", "Nome do doador", "Sigla  Partido",
                                          "Nome candidato"])["Valor receita"].transform("sum")
receitas_cidade = (itabira_receitas2016[["CPF/CNPJ do doador", "Nome do doador", "Sigla  Partido", "Nome candidato",
                             "receita"]]).drop_duplicates().sort_values("receita", ascending = False)
receitas_cidade.head(50)

# %%
# 4. Quem doou mais - PREFEITO

itabira_rec_pref["receita"] = itabira_rec_pref.groupby(["CPF/CNPJ do doador", "Nome do doador", "Sigla  Partido",
                                          "Nome candidato"])["Valor receita"].transform("sum")
receitas_itabira_pref = (itabira_rec_pref[["CPF/CNPJ do doador", "Nome do doador", "Sigla  Partido", "Nome candidato",
                             "receita"]]).drop_duplicates().sort_values("receita", ascending = False)
receitas_itabira_pref.head(50)

# %%
# 4. Quem doou mais - VEREADOR

itabira_receitas2016_ver["receita"] = itabira_receitas2016_ver.groupby(["CPF/CNPJ do doador", "Nome do doador", "Sigla  Partido",
                                          "Nome candidato"])["Valor receita"].transform("sum")
receitas_itabira_ver = (itabira_receitas2016_ver[["CPF/CNPJ do doador", "Nome do doador", "Sigla  Partido", "Nome candidato",
                             "receita"]]).drop_duplicates().sort_values("receita", ascending = False)
receitas_itabira_ver.head(50)

# %% [markdown]
# 5. Tem empresa/pessoa que doou para mais de um candidato
#
#
# Aparentemente não, mas precisamos checar melhor essa informação, não sei como...

# %%
# 6. Total recebido por partido

itabira_receitas2016["gasto_part"] = itabira_receitas2016.groupby(["Sigla  Partido"])["Valor receita"].transform("sum")
total_partido = (itabira_receitas2016)[["Sigla  Partido", "gasto_part"]].drop_duplicates().sort_values("gasto_part",
                                                                                           ascending = False)

total_partido

# %% [markdown]
# Os três primeiros partidos tinham candidatos a prefeito, mas quem ganhou a eleição foi o que investiu menos dinheiro - **PV R$ 138.692,00**. O **PDT** investiu quase o dobro do PV.

# %% [markdown]
# #### Base Despesas

# %%
# Separando prefeito e vereador

itabira_pref = cidade.loc[cidade["Cargo"] == "Prefeito"]
itabira_ver = cidade.loc[cidade["Cargo"] == "Vereador"]


# Quem gastou mais em Barão de Cocais em 2016? Prefeitos

itabira_pref["despesas"] = itabira_pref.groupby(["CPF do candidato", "Sigla  Partido",
                                             "Nome candidato"])["Valor despesa"].transform("sum")
despesas_itabira_pref = (itabira_pref[["CPF do candidato", "Sigla  Partido", "Nome candidato",
                                  "despesas"]].drop_duplicates().sort_values("despesas", ascending = False))
despesas_itabira_pref

# %%
# Quem gastou mais em Barão de Cocais em 2016? Vereador

itabira_ver["despesas"] = itabira_ver.groupby(["CPF do candidato", "Sigla  Partido",
                                             "Nome candidato"])["Valor despesa"].transform("sum")
despesas_itabira_ver = (itabira_ver[["CPF do candidato", "Sigla  Partido", "Nome candidato",
                                  "despesas"]].drop_duplicates().sort_values("despesas", ascending = False))
despesas_itabira_ver.head(50)

# %%
# Qual a média dos gastos? - Prefeitos

despesas_itabira_pref.describe()

# %%
# Qual a média dos gastos? - Vereador

despesas_itabira_ver.describe()

# %%
# Ranking de despesas - Prefeitos

gastos_pref = itabira_pref[["Tipo despesa", "Valor despesa"]]
gastos_pref = (gastos_pref.groupby(["Tipo despesa"]).sum().sort_values("Valor despesa", ascending = False))
gastos_pref

# %%
# Ranking de despesas - Vereador

gastos_ver = itabira_ver[["Tipo despesa", "Valor despesa"]]
gastos_ver = (gastos_ver.groupby(["Tipo despesa"]).sum().sort_values("Valor despesa", ascending = False))
gastos_ver

# %%
# Quais fornecedores ganharam mais dinheiro?

cidade["despesas"] = cidade.groupby(["CPF/CNPJ do fornecedor", "Nome do fornecedor"])["Valor despesa"].transform("sum")
desp_cidade = (cidade[["CPF/CNPJ do fornecedor", "Nome do fornecedor", "despesas"]]).drop_duplicates().sort_values("despesas", ascending = False)
desp_cidade.head(50)

# %%
# Quais fornecedores ganharam mais dinheiro? - Geral

cidade["despesas"] = cidade.groupby(["CPF/CNPJ do fornecedor", "Nome do fornecedor","Sigla  Partido",
                                   "Nome candidato"])["Valor despesa"].transform("sum")
despesas_cidade = (cidade[["CPF/CNPJ do fornecedor", "Nome do fornecedor","Sigla  Partido", "Nome candidato",
                         "despesas"]]).drop_duplicates().sort_values("despesas", ascending = False)
despesas_cidade.head(50)

# %%
# Quais fornecedores ganharam mais dinheiro? - Geral

itabira_pref["despesas"] = itabira_pref.groupby(["CPF/CNPJ do fornecedor", "Nome do fornecedor","Sigla  Partido",
                                   "Nome candidato"])["Valor despesa"].transform("sum")
despesas_itabira_pref = (itabira_pref[["CPF/CNPJ do fornecedor", "Nome do fornecedor","Sigla  Partido", "Nome candidato",
                         "despesas"]]).drop_duplicates().sort_values("despesas", ascending = False)
despesas_itabira_pref.head(50)

# %%
# Quais fornecedores ganharam mais dinheiro? - Geral

itabira_ver["despesas"] = itabira_ver.groupby(["CPF/CNPJ do fornecedor", "Nome do fornecedor","Sigla  Partido",
                                   "Nome candidato"])["Valor despesa"].transform("sum")
despesas_itabira_ver = (itabira_ver[["CPF/CNPJ do fornecedor", "Nome do fornecedor","Sigla  Partido", "Nome candidato",
                         "despesas"]]).drop_duplicates().sort_values("despesas", ascending = False)
despesas_itabira_ver.head(50)

# %%
# Os candidatos gastaram com os mesmos fornecedores? - Precisa de análise

# %%
# Média de gastos dos partidos por candidato

# 1º Gastos por partido
cidade["gasto_part"] = cidade.groupby(["Sigla  Partido"])["Valor despesa"].transform("sum")
gasto_partido = (cidade)[["Sigla  Partido", "gasto_part"]].drop_duplicates().sort_values("gasto_part", ascending = False)

gasto_partido

# %%
# Encontrar a quantidade de candidatos por partido
cidade["candidatos"] = cidade.groupby(["Sigla  Partido"])["Nome candidato"].transform("nunique")


gasto_partido = cidade[["Sigla  Partido", "gasto_part", "candidatos"]].drop_duplicates()


# Calculando a média de gastos
gasto_partido["media"] = gasto_partido["gasto_part"] / gasto_partido["candidatos"]
gasto_partido = gasto_partido.sort_values(by = "media", ascending = False)
gasto_partido

# %%
tidy = pd.melt(cidade.reset_index(),
               id_vars=['game_id', 'date'], value_vars=['away_team', 'home_team'],
               value_name='team')
tidy.head()
