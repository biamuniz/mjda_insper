# %% [markdown]
# <a href="https://colab.research.google.com/github/biamuniz/mjda_insper_osint/blob/main/Aula_9_Quem_guarda%2C_tem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python --version
# Out:
# Python 3.7.12

# %% [markdown]
# Como vocês aprenderam, vamos importar os módulos que serão usados. Neste caso, são apenas 2: o Requests, para fazer requisições online, e o Pandas, para lidar com os dados.

# %%
import requests
import pandas as pd
from pandas import json_normalize

# %% [markdown]
# Após importar os módulos, vamos definir algumas variáveis básicas, como o código do canal a ser analisado e a chave que o Google dá para usar a API

# %%
chave="colocar minha chave"

# %%
canal="UCJNH25X9d9Nc7h3Rd7cm7bw" ## canal da frannerd

# %% [markdown]
# **Primeira coisa**: precisamos pegar os dados básicos do canal, incluindo o código da playlist de uploads. Iniciamos formatando a URL.

# %%
url_canal = f"https://www.googleapis.com/youtube/v3/channels?part=id%2Csnippet%2CcontentDetails%2Cstatistics&id={canal}&key={chave}"

# %%
url_canal
# Out:
# 'https://www.googleapis.com/youtube/v3/channels?part=id%2Csnippet%2CcontentDetails%2Cstatistics&id=UCJNH25X9d9Nc7h3Rd7cm7bw&key=AIzaSyAGmTusB0VNpqemFSOwrqsnBfHdFqNqL8k'

# %% [markdown]
# É hora de fazer a 1ª requisição! Vamos acionar a API para pegar o código da playlist de uploads

# %%
resposta = requests.get(url_canal)

# %%
resposta
# Out:
# <Response [200]>

# %%
dados_canal=resposta.json()

# %% [markdown]
# Com a resposta correta (código 200), é hora de achar o código dentro do dicionário que a API do Google devolve

# %%
dados_canal.keys()
# Out:
# dict_keys(['kind', 'etag', 'pageInfo', 'items'])

# %%
codigo_playlist=dados_canal["items"][0]["contentDetails"]["relatedPlaylists"]["uploads"]

# %% [markdown]
# **Segundo passo**: com o código, podemos acionar o outro endpoint  para pegar a lista de vídeos.

# %%
url_videos=f'https://www.googleapis.com/youtube/v3/playlistItems?part=snippet,contentDetails&maxResults=50&playlistId={codigo_playlist}&key={chave}'

# %%
url_videos
# Out:
# 'https://www.googleapis.com/youtube/v3/playlistItems?part=snippet,contentDetails&maxResults=50&playlistId=UUJNH25X9d9Nc7h3Rd7cm7bw&key=AIzaSyAGmTusB0VNpqemFSOwrqsnBfHdFqNqL8k'

# %% [markdown]
# A nova URL está pronta. Agora é fazer uma nova requisição

# %%
resposta_videos = requests.get(url_videos)

# %%
dados_videos=resposta_videos.json()

# %% [markdown]
# Mesma coisa: com os dados que a API devolveu, é preciso encontrar onde estão só as informações sobre os vídeos

# %%
dados_videos.keys()
# Out:
# dict_keys(['kind', 'etag', 'nextPageToken', 'items', 'pageInfo'])

# %%
videos=dados_videos['items']

# %% [markdown]
# Pronto! Agora a parte mais fácil: para analisar os dados, o Pandas é a melhor opção. Há uma função que encaixa os JSONs em um DataFrame corretamente. É o json_normalize.

# %%
df=json_normalize(videos)

# %%
df
# Out:
#                     kind  ... contentDetails.videoPublishedAt
# 0   youtube#playlistItem  ...            2021-09-18T18:49:12Z
# 1   youtube#playlistItem  ...            2021-08-07T13:37:30Z
# 2   youtube#playlistItem  ...            2021-07-31T18:20:36Z
# 3   youtube#playlistItem  ...            2021-07-12T14:59:55Z
# 4   youtube#playlistItem  ...            2021-05-16T16:03:08Z
# 5   youtube#playlistItem  ...            2021-04-16T13:50:34Z
# 6   youtube#playlistItem  ...            2021-03-19T14:14:42Z
# 7   youtube#playlistItem  ...            2021-01-29T18:57:28Z
# 8   youtube#playlistItem  ...            2021-01-08T15:30:15Z
# 9   youtube#playlistItem  ...            2020-12-11T15:48:34Z
# 10  youtube#playlistItem  ...            2020-10-30T15:56:09Z
# 11  youtube#playlistItem  ...            2020-09-12T14:19:54Z
# 12  youtube#playlistItem  ...            2020-08-14T14:52:05Z
# 13  youtube#playlistItem  ...            2020-07-31T14:17:02Z
# 14  youtube#playlistItem  ...            2020-07-24T15:09:39Z
# 15  youtube#playlistItem  ...            2020-07-17T13:02:47Z
# 16  youtube#playlistItem  ...            2020-07-04T15:31:52Z
# 17  youtube#playlistItem  ...            2020-05-29T15:48:10Z
# 18  youtube#playlistItem  ...            2020-05-15T13:12:05Z
# 19  youtube#playlistItem  ...            2020-05-01T12:56:33Z
# 20  youtube#playlistItem  ...            2020-04-24T13:29:20Z
# 21  youtube#playlistItem  ...            2020-04-17T15:36:43Z
# 22  youtube#playlistItem  ...            2020-04-03T13:12:28Z
# 23  youtube#playlistItem  ...            2020-03-27T14:04:46Z
# 24  youtube#playlistItem  ...            2020-03-20T14:09:41Z
# 25  youtube#playlistItem  ...            2020-02-28T14:24:12Z
# 26  youtube#playlistItem  ...            2020-02-14T13:22:12Z
# 27  youtube#playlistItem  ...            2020-02-07T15:44:45Z
# 28  youtube#playlistItem  ...            2020-01-24T14:23:39Z
# 29  youtube#playlistItem  ...            2020-01-10T13:46:11Z
# 30  youtube#playlistItem  ...            2020-01-03T14:31:09Z
# 31  youtube#playlistItem  ...            2019-12-20T14:06:12Z
# 32  youtube#playlistItem  ...            2019-12-13T14:17:17Z
# 33  youtube#playlistItem  ...            2019-11-29T14:41:51Z
# 34  youtube#playlistItem  ...            2019-11-08T14:51:48Z
# 35  youtube#playlistItem  ...            2019-11-01T17:17:20Z
# 36  youtube#playlistItem  ...            2019-09-27T14:08:28Z
# 37  youtube#playlistItem  ...            2019-09-20T13:26:08Z
# 38  youtube#playlistItem  ...            2019-09-13T13:18:57Z
# 39  youtube#playlistItem  ...            2019-09-01T12:00:21Z
# 40  youtube#playlistItem  ...            2019-08-23T13:40:58Z
# 41  youtube#playlistItem  ...            2019-08-09T13:03:33Z
# 42  youtube#playlistItem  ...            2019-08-02T12:43:24Z
# 43  youtube#playlistItem  ...            2019-07-26T13:25:33Z
# 44  youtube#playlistItem  ...            2019-07-12T13:18:34Z
# 45  youtube#playlistItem  ...            2019-06-28T13:42:00Z
# 46  youtube#playlistItem  ...            2019-06-21T14:10:03Z
# 47  youtube#playlistItem  ...            2019-06-14T13:17:03Z
# 48  youtube#playlistItem  ...            2019-05-31T07:47:42Z
# 49  youtube#playlistItem  ...            2019-05-24T14:19:57Z
#
# [50 rows x 31 columns]

# %% [markdown]
# Legal, mas cadê o resto dos vídeos? Como funcionam os tokens

# %%
dados_videos.keys()
# Out:
# dict_keys(['kind', 'etag', 'nextPageToken', 'items', 'pageInfo'])

# %%
proxima_pagina=dados_videos['nextPageToken']

# %%
url_videos=f'https://www.googleapis.com/youtube/v3/playlistItems?part=snippet,contentDetails&maxResults=50&playlistId={codigo_playlist}&key={chave}&pageToken={proxima_pagina}'

# %%
url_videos
# Out:
# 'https://www.googleapis.com/youtube/v3/playlistItems?part=snippet,contentDetails&maxResults=50&playlistId=UUJNH25X9d9Nc7h3Rd7cm7bw&key=AIzaSyAGmTusB0VNpqemFSOwrqsnBfHdFqNqL8k&pageToken=EAAaBlBUOkNESQ'

# %%
resposta_videos = requests.get(url_videos)
dados_videos=resposta_videos.json()
videos=dados_videos['items']
temp=json_normalize(videos)
